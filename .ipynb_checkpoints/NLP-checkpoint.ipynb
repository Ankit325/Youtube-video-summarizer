# %%
# !pip install youtube_transcript_api
# Out:
# Collecting youtube_transcript_api
#   Using cached youtube_transcript_api-0.4.4-py3-none-any.whl (22 kB)
# Requirement already satisfied: requests in c:\users\ankit\anaconda3\lib\site-packages (from youtube_transcript_api) (2.27.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ankit\anaconda3\lib\site-packages (from requests->youtube_transcript_api) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ankit\anaconda3\lib\site-packages (from requests->youtube_transcript_api) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\ankit\anaconda3\lib\site-packages (from requests->youtube_transcript_api) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ankit\anaconda3\lib\site-packages (from requests->youtube_transcript_api) (1.26.7)
# Installing collected packages: youtube_transcript_api
# Successfully installed youtube_transcript_api-0.4.4

# %%
import youtube_transcript_api
from youtube_transcript_api import YouTubeTranscriptApi
import nltk
import re
from nltk.corpus import stopwords
import sklearn
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
link = "https://www.youtube.com/watch?v=W6NZfCO5SIk" 
unique_id = link.split("=")[-1]
sub = YouTubeTranscriptApi.get_transcript(unique_id)  
subtitle = " ".join([x['text'] for x in sub])

# %% [markdown]
# Using TF-IDF

# %%
from nltk.tokenize import sent_tokenize

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ankit\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
subtitle = subtitle.replace("n","")
sentences = sent_tokenize(subtitle)

# %%
subtitle
# Out:
# "I this 3-miute itroductio, I'm goig\nto aswer four frequetly asked questios about JavaScript. \nWhat is JavaScript, what ca you do with it, where does JavaScript code ru ad\nwhat is the differece betwee JavaScript ad ECMAScript. So let's\nstart with the first questio. What is JavaScript? JavaScript is oe of the most\npopular ad widely used programmig laguages i the world right ow. It's\ngrowig faster tha ay other programmig laguages ad big compaies\nlike Netflix, Walmart, ad PayPal build etire applicatios aroud JavaScript.\nAd here's the average salary of a JavaScript developer i the Uited\nStates. That is $72,000 a year. So it's a great opportuity to get a good\njob out of learig JavaScript. You ca work as a frot-ed developer or a\nback-ed developer or a full stack developer who kows both the frot ed\nad the back ed. Now, the secod questio. What ca you do with JavaScript? For a\nlog time, javascript was oly used i browsers to\nbuild iteractive web pages some developers refer to javascript as a toy\nlaguage but those days are goe because of huge commuity support ad\nivestmets by large compaies like Facebook ad Google these days you ca\nbuild full-blow web or mobile apps as well as real time etworkig\napplicatios like chats ad video streamig services commad-lie tools or\neve games here's a example a third questio where does JavaScript code ru\njavascript was origially desiged to ru oly i browsers so every browser\nhas what we call a JavaScript egie that ca execute JavaScript code for\nexample the JavaScript egies i firefox ad chrome are SpiderMokey ad\nv8 i 2009 a very clever egieer called Rya Dahl took the ope-source\nJavaScript egie i chrome ad embedded it iside a C++ program he called that\nprogram ode the ode is a C++ program that icludes Google's v8 JavaScript\negie ow with this we ca ru JavaScript code out\nof a browser so we ca pass our JavaScript code to ode for executio\nad this meas with JavaScript we ca build the backed for our web ad mobile\napplicatios so i a utshell JavaScript code ca be ru iside of a browser or\ni ode browsers ad ode provide a rutime eviromet for our JavaScript\ncode ad fially the last questio what is the differece betwee JavaScript ad\nEggma script well ECMO script is just a specificatio javascript is a\nprogrammig laguage that cofirms to this specificatio so we have this\norgaizatio called a comma which is resposible for defiig stadards they\ntake care of this Eggma script specificatio the first versio of\nEggma script was released i 1997 the startig from 2015\nACMA has bee workig o aual releases of a ewest specificatio so i 2015\nthey released a kimoo script 2015 which is also called ECMO script versio 6 or\nes6 for short this specificatio defied may ew features for JavaScript alright\neough theory let's see javascript i actio so every\nbrowser has a JavaScript egie ad we ca easily write JavaScript code here\nwithout ay additioal tools of course this is ot how we build real-world\napplicatios but this is just for a quick demo so ope up Chrome right click\no a empty area ad go to ispect ow this opes up chrome developer tools\nhere select the cosole tab this is our JavaScript cosole ad we ca write ay\nvalid JavaScript code here so type this cosole dot log put a sigle code here\nad the hello world aother sigle code to termiate close the paretheses ad\nadd a semicolo at the ed ow as you go through the course you're goig to\nuderstad exactly what all this meas for ow do't worry about it so ow I'll\npress ENTER ad you ca see the hello world message o the cosole we ca also\nwrite mathematical expressios here for example two plus two we get four or we\nca do somethig like this alert practices sigle coat yo eter ad\nhere's a alert i the ext lecture I'm goig to talk about settig up your\ndevelopmet eviromet for writig JavaScript code i order to write javascript code you\need a code editor there are various code editors out there icludig Visual\nStudio code or yes code sublime text atom ad so o\nout of  ...

# %%
organized_sent = {k:v for v,k in enumerate(sentences)}

# %%
tf_idf = TfidfVectorizer(min_df=2, 
                                    strip_accents='unicode',
                                    max_features=None,
                                    lowercase = True,
                                    token_pattern=r'w{1,}',
                                    ngram_range=(1, 3), 
                                    use_idf=1,
                                    smooth_idf=1,
                                    sublinear_tf=1,
                                    stop_words = 'english')

# %%
import numpy as np

# %%
from numpy import *

# %%
sentence_vectors = tf_idf.fit_transform(sentences)
sent_scores = np.array(sentence_vectors.sum(axis=1)).ravel()
# Out:
# C:\Users\ankit\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:388: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['w'] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '

# %%
N = 3
top_n_sentences = [sentences[index] for index in np.argsort(sent_scores, axis=0)[::-1][:N]]

# %%
# mapping the scored sentences with their indexes as in the subtitle
mapped_sentences = [(sentence,organized_sent[sentence]) for sentence in top_n_sentences]
# Ordering the top-n sentences in their original order
mapped_sentences = sorted(mapped_sentences, key = lambda x: x[1])
ordered_sentences = [element[0] for element in mapped_sentences]
# joining the ordered sentence
summary = " ".join(ordered_sentences)

# %%
summary
# Out:
# 'What is JavaScript, what ca you do with it, where does JavaScript code ru ad\nwhat is the differece betwee JavaScript ad ECMAScript. JavaScript is oe of the most\npopular ad widely used programmig laguages i the world right ow. You ca work as a frot-ed developer or a\nback-ed developer or a full stack developer who kows both the frot ed\nad the back ed.'

# %% [markdown]
# Summarization using BART

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Using cached transformers-4.18.0-py3-none-any.whl (4.0 MB)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Using cached huggingface_hub-0.5.1-py3-none-any.whl (77 kB)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\ankit\anaconda3\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: filelock in c:\users\ankit\anaconda3\lib\site-packages (from transformers) (3.3.1)
# Requirement already satisfied: tqdm>=4.27 in c:\users\ankit\anaconda3\lib\site-packages (from transformers) (4.62.3)
# Requirement already satisfied: requests in c:\users\ankit\anaconda3\lib\site-packages (from transformers) (2.27.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\ankit\anaconda3\lib\site-packages (from transformers) (21.0)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Using cached tokenizers-0.11.6-cp39-cp39-win_amd64.whl (3.2 MB)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\ankit\anaconda3\lib\site-packages (from transformers) (2021.8.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\ankit\anaconda3\lib\site-packages (from transformers) (1.22.3)
# Collecting sacremoses
#   Using cached sacremoses-0.0.49-py3-none-any.whl (895 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\ankit\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.10.0.2)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\ankit\anaconda3\lib\site-packages (from packaging>=20.0->transformers) (3.0.4)
# Requirement already satisfied: colorama in c:\users\ankit\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ankit\anaconda3\lib\site-packages (from requests->transformers) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\ankit\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ankit\anaconda3\lib\site-packages (from requests->transformers) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ankit\anaconda3\lib\site-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: joblib in c:\users\ankit\anaconda3\lib\site-packages (from sacremoses->transformers) (1.1.0)
# Requirement already satisfied: six in c:\users\ankit\anaconda3\lib\site-packages (from sacremoses->transformers) (1.16.0)
# Requirement already satisfied: click in c:\users\ankit\anaconda3\lib\site-packages (from sacremoses->transformers) (8.0.3)
# Installing collected packages: tokenizers, sacremoses, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.5.1 sacremoses-0.0.49 tokenizers-0.11.6 transformers-4.18.0

# %%
import transformers
from transformers import BartTokenizer, BartForConditionalGeneration

# %%
tokenizer = BartTokenizer.from_pretrained('facebook/bart-large-cnn')
model = BartForConditionalGeneration.from_pretrained('facebook/bart-large-cnn')

# %%
input_tensor = tokenizer.encode( subtitle, return_tensors="pt", max_length=512)
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.

# %%
outputs_tensor = model.generate(input_tensor, max_length=160, min_length=120, length_penalty=2.0, num_beams=4, early_stopping=True)
outputs_tensor
# Out:
# tensor([[    2,     0, 18434,    16,    65,     9,     5,   144,  3924,   341,
#            586,   119,  1023,   784, 11993,  3443,   939,     5,   232,     4,
#             85,    18,   341,     7,  1119,   455,    12, 42671,  3748,    50,
#           1830,  3798,    25,   157,    25,   588,    86,  4400,  6014,  1023,
#            518,     4,     2]])

# %%
print(tokenizer.decode(outputs_tensor[0]))
# Out:
# </s><s> JavaScript is one of the most widely used programmig laguages i the world. It's used to build full-blow web or mobile apps as well as real time etworkig services. The average salary of a JavaScript developer i the Uited States is $72,000 a year. You can get a good job out of learning JavaScript with our guide to the language and how it's used in the real world. We'll also talk about the differences between JavaScript and ECMAScript. We hope this guide will help you get the most out of your knowledge of the language.</s>

# %%
from transformers import pipeline

# %%
summarizer = pipeline('summarization')
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 (https://huggingface.co/sshleifer/distilbart-cnn-12-6)

# %%
print(subtitle)
# Out:
# I this 3-miute itroductio, I'm goig
# to aswer four frequetly asked questios about JavaScript.
# What is JavaScript, what ca you do with it, where does JavaScript code ru ad
# what is the differece betwee JavaScript ad ECMAScript. So let's
# start with the first questio. What is JavaScript? JavaScript is oe of the most
# popular ad widely used programmig laguages i the world right ow. It's
# growig faster tha ay other programmig laguages ad big compaies
# like Netflix, Walmart, ad PayPal build etire applicatios aroud JavaScript.
# Ad here's the average salary of a JavaScript developer i the Uited
# States. That is $72,000 a year. So it's a great opportuity to get a good
# job out of learig JavaScript. You ca work as a frot-ed developer or a
# back-ed developer or a full stack developer who kows both the frot ed
# ad the back ed. Now, the secod questio. What ca you do with JavaScript? For a
# log time, javascript was oly used i browsers to
# build iteractive web pages some developers refer to javascript as a toy
# laguage but those days are goe because of huge commuity support ad
# ivestmets by large compaies like Facebook ad Google these days you ca
# build full-blow web or mobile apps as well as real time etworkig
# applicatios like chats ad video streamig services commad-lie tools or
# eve games here's a example a third questio where does JavaScript code ru
# javascript was origially desiged to ru oly i browsers so every browser
# has what we call a JavaScript egie that ca execute JavaScript code for
# example the JavaScript egies i firefox ad chrome are SpiderMokey ad
# v8 i 2009 a very clever egieer called Rya Dahl took the ope-source
# JavaScript egie i chrome ad embedded it iside a C++ program he called that
# program ode the ode is a C++ program that icludes Google's v8 JavaScript
# egie ow with this we ca ru JavaScript code out
# of a browser so we ca pass our JavaScript code to ode for executio
# ad this meas with JavaScript we ca build the backed for our web ad mobile
# applicatios so i a utshell JavaScript code ca be ru iside of a browser or
# i ode browsers ad ode provide a rutime eviromet for our JavaScript
# code ad fially the last questio what is the differece betwee JavaScript ad
# Eggma script well ECMO script is just a specificatio javascript is a
# programmig laguage that cofirms to this specificatio so we have this
# orgaizatio called a comma which is resposible for defiig stadards they
# take care of this Eggma script specificatio the first versio of
# Eggma script was released i 1997 the startig from 2015
# ACMA has bee workig o aual releases of a ewest specificatio so i 2015
# they released a kimoo script 2015 which is also called ECMO script versio 6 or
# es6 for short this specificatio defied may ew features for JavaScript alright
# eough theory let's see javascript i actio so every
# browser has a JavaScript egie ad we ca easily write JavaScript code here
# without ay additioal tools of course this is ot how we build real-world
# applicatios but this is just for a quick demo so ope up Chrome right click
# o a empty area ad go to ispect ow this opes up chrome developer tools
# here select the cosole tab this is our JavaScript cosole ad we ca write ay
# valid JavaScript code here so type this cosole dot log put a sigle code here
# ad the hello world aother sigle code to termiate close the paretheses ad
# add a semicolo at the ed ow as you go through the course you're goig to
# uderstad exactly what all this meas for ow do't worry about it so ow I'll
# press ENTER ad you ca see the hello world message o the cosole we ca also
# write mathematical expressios here for example two plus two we get four or we
# ca do somethig like this alert practices sigle coat yo eter ad
# here's a alert i the ext lecture I'm goig to talk about settig up your
# developmet eviromet for writig JavaScript code i order to write javascript code you
# eed a code editor there are various code editors out there icludig Visual
# Studio code or yes code sublime text atom ad so o
# out of these my favorite is Visual Studio code that you ca dowload from
# code that Visual Studio comm it's a very simple lightweight cross-platform ad
# powerful editor so if you do't have Visual Studio code o your machie go
# ahead ad dowload it the other thig I wated to istall is ote you ca
# dowload ote from odejs org ow techically you do't
# ecessarily eed kow to execute JavaScript because as I explaied before
# you ca execute JavaScript code iside of a browser or EdNote but it's good to
# have ode o your machie because we use that to istall third-party libraries
# ad also later i this sectio I'm goig to show you a preview of ode so pause
# the video ow ad dowload Visual Studio code as well as ote oce you're doe
# come back cotiue watchig to create a ew folder call that J s
# dash basics the ame does't really matter we just wat to have a folder for
# writig all the code i this course ow drag ad drop this folder ito visual
# studio code okay we've got this folder ope let's add a ew file here idex dot
# HTML ow you do't really eed to kow HTML i order to take this course but if
# you wat to be a frot-ed developer you should kow your HTML well ow i this
# file I wat you to type a exclamatio mark ad the press tab this geerates
# some basic HTML boilerplate we do't really care about ay of this code here
# we're goa use this as a host for our JavaScript code you're goa see that i
# the ext lecture so save the chages ow ope the extesios tab here
# here i this box search for live server so live server is a very lightweight web
# server that we're goig to use to serve our web applicatio so istall this the
# you will have to restart Visual Studio code whe you're doe go to the Explorer
# tab right click idex.html ad select ope with live server this will ope up Chrome or your default
# browser ad poit it to this address that's where our web applicatio is
# served from ow curretly we have a empty page ow to make sure that
# everythig is workig properly let's go back to visual studio code here i the
# body sectio let's add a h1 press tab ad type hello world ow save the
# chages back i the browser we ca see this page is refreshed automatically ad
# we've got the hello world headig here i the ext lecture you're goig to
# write your first JavaScript code all right ow we're ready to write our
# first Java Script code i order to write JavaScript code here we eed a script
# elemet there are two places where we ca add a script elemet we ca add it
# here i a head sectio or i the body sectio the best practice is to put the
# script elemet at the ed of the body sectio after all the existig elemets
# so here after h1 I'm goa type script ad press tab this is our script elemet
# ow why did I say that as a best practice you should put this script
# elemet here well there are two reasos for that oe reaso is that the browser
# parses this file from top to bottom so if you put this script elemet here i
# the head sectio you might have a lot of JavaScript code there so your browser
# may get busy parsig ad executig that JavaScript code ad it wo't be able to
# reder the cotet of the page so this will create a bad user experiece your
# user looks at your web page it's white or blak while your browser is busy
# parsig ad executig your JavaScript code so that's reaso 1 the secod
# reaso is that almost always the code that we have i betwee script elemets
# eeds to talk to the elemets o this web page for example we may wat to show
# or hide some elemets so by addig the code here at the ed of the body sectio
# we'll be cofidet that all these elemets are redered by the browser ow
# there are exceptios to this rule sometimes you're usig third-party code
# that has to be placed i the head sectio but these are exceptios as I
# told you before as a best practice you should add your JavaScript code at the
# ed of the body sectio ow here we're goa write the same code that you wrote
# i the last lecture cosole dot log hello world but we're goig to talk
# about this i a little bit more detail what we have here is a statemet a
# statemet is a piece of code that expresses a actio to be carried out i
# this case we wat to log a message o the cosole all statemets
# i JavaScript should be termiated by a semicolo what we have here i betwee
# sigle codes is called a strig a strig is a sequece of
# characters ow i JavaScript we also have this otatio we ca add two
# slashes ad this represets a comet so here we ca add some descriptio to our
# code ad this descriptio is igored by the JavaScript egie it's ot executed
# it's purely for documetig the code whe you waa explai to other
# developers why you have writte this code this way you do't explai what the
# code does because that should be clear i the code itself so here I do't wat
# to write somethig like loggig somethig o the cosole that's so
# obvious i the code right istead we wat to explai why's ad a house so for
# this demo I'm just goa add a simple commet this is my first JavaScript code
# ow save the chages back i the browser we eed to brig the cosole back up so
# right click somewhere ad go to ispect or alteratively you ca use a shortcut
# that is alt commad a eye o Mac or alt cotrol eye o widows that brigs up
# the cosole tab if the cosole tab is ot immediately visible make sure to
# select it here ad here you ca see the hello world message ow while we ca easily write javascript
# code i betwee the script elemet i a real-world applicatio you have
# thousads or eve millios of code we do't wat to write all that code i
# lie here we wat to extract ad separate our JavaScript code from our
# HTML code let me give you a metaphor thik of your house i your bedroom you
# have your bed ad your clothes you do't store your clothes i the kitche this
# is what we call separatio of cocers we have the same priciple i
# programmig so we wat to separate HTML which is all about cotet from
# JavaScript which is all about behavior how should your web page behave what
# should happe whe we hover our mouse over a give elemet maybe somethig
# should pop up maybe somethig should be hidde so we use JavaScript to implemet
# behavior so ope up the Explorer widow add a ew file cut i idex the j/s ow
# back i idex dot HTML cut all this JavaScript code here ad the paste it
# i idex J s ow i this simple applicatio we have a sigle file a
# sigle javascript file i a real world applicatio we have hudreds or eve
# thousads of JavaScript files later i the course you will lear how to combie
# these files ito a budle ad serve that budle to the cliet ow save the
# chages back i idex.html ow that all our JavaScript code is i a separate
# file we eed to referece that file here so let's add a attribute here SRC which
# is short for source ad set it to idex that j/s so this tells the browser that
# our JavaScript code is ow i idex that is save the chages back i the browser
# you ca still see the hello world message ad that cofirms that our code
# is still workig i the ext lecture we are goig to execute this code i ode so i the last lecture we executed this
# piece of JavaScript code iside of a browser i this lecture I'm goig to
# show you how to ru the same code i ode so I'm assumig that you have
# istalled ode o your machie if ot head over to ode.js org ad dowload
# the latest versio of ode ow if you're o Widows ope up commad prompt if
# you're o Mac ope up termial ad head over to the folder you created earlier
# ow i this folder we ru ode ad pass the ame of our javascript file that is
# idex dot JSON c ode is a program that icludes google's v8 JavaScript egie
# we ca give it a piece of JavaScript code ad it will execute that code for
# us just like how we ca execute some JavaScript code i a browser so ode is
# a rutime eviromet for executig JavaScript code ow let me show you a
# tip here i vs code we have a itegrated termial so you're goa have
# to explicitly ope up a separate termial widow so here o the top uder
# the View meu look we have itegrated termial ote the shortcut here that's
# the shortcut for mac ad widows you're goa have a differet shortcut so
# select this ad here's our itegrated termial poitig to the same folder
# where we created our files so you do't have to explicitly avigate to this
# folder ad here we ca ru ode idexed at j/s as well ow i this course we're
# ot goa work with ode aymore because ode is a complex separate topic i fact
# I have a comprehesive course about ode with 14 hours of cotet so oce you
# fiish this course if you wat to lear ode you ca always look at my ote
# course well hello it's mahshar thak you for
# watchig my javascript tutorial I just wated to quickly let you kow that this
# tutorial is part of my complete JavaScript course where you ca lear
# about all the essetial cocepts i JavaScript the course is packed with
# lots of exercises ad solutios ad by the ed of watchig the course you will
# also receive a certificate of completio i case you're iterested you ca fid a
# lik i the video descriptio ad if ot that's perfectly fie cotiue watchig
# as the ext sectio is comig up let's start this sectio by a discussio
# of variables which are oe of the most fudametal cocepts i JavaScript ad
# ay other programmig laguages i programmig we use a variable to store
# data temporarily i a computer's memory so we store our data somewhere ad give
# that memory locatio ad ame ad with this ame we ca read the data at the
# give locatio i the future here is a metaphor thik of the boxes you use to
# orgaize your stuff you put your stuff i various boxes ad put a label o each
# box with this you ca easily fid your stuff right a variable is like a box
# what we put iside the box is the value that we assig to a variable that's the
# data ad the label that we put o the box is the ame of our variable ow
# let's see this i code so here i idex Jas I'm goa declare a variable ow
# previously i the old days before es6 we use the VAR keyword to declare a
# variable but there are issues with var as you will fid out later i the course
# so goig forward from es6 the best practice is to use the lead keyword to
# declare a variable ow we eed to give this variable a ame or a idetifier
# ad this is like the label we put o a box so I'm goa call this ame ad
# fially we eed to termiate this declaratio with a semicolo ow let's
# log this o the cosole ad see what we get
# so cosole that log ame oce agai we eed to termiate this statemet with a
# semicolo save the chages ad here i the cosole we see udefied so by
# default variables that we defied i JavaScript their value is udefied ow
# we ca optioally iitialize this variable so I'm goa set this to a
# strig which is a sequece of characters like Marsh ote that I'm usig sigle
# quote you ca also use double quotes differet developers have differet
# prefereces but it's more commo to use sigle quotes for declarig strigs i
# JavaScript ow whe we save the chages istead of oe
# we see Marsh o the cosole so here i this example we have declared a variable
# called ame ad we have set that to this value to this strig ow we have a few
# rules for amig these variables here are the rules
# first is that they caot be a reserved keyword so i JavaScript we have
# reserved keywords let is oe of them you also have if else VAR ad so o ow
# you do't have to memorize this list if you try to use oe of these ames you're
# goa get a error for example if I chage this to if otice red uderlie
# this is idicatig that this is ot a valid idetifier okay so revert it back
# ow the secod rule is that they should be meaigful we wat to have meaigful
# ames like meaigful labels I've see developers usig ames like a or PE or a
# oe or I do't kow X these variable ames do ot give us ay clue what is
# the purpose of these variables what kid of data are restorig at that memory
# locatio so always use meaigful ad descriptive ames okay ow back to ame
# the third rule is that they caot start with a umber so we caot have a
# variable like oe ame but agai goig back to the secod rule why would you
# wat to call it variable oe ame it's meaigless right so always use
# meaigful ames the fourth rule is that they caot cotai a space or - so if
# you have multiple words you eed to put them together here is a example let's
# imagie we wat to declare a variable called first ame so first ame ad ote
# that here I'm usig camel otatio so the first letter of the first word
# should be lowercase ad the first letter of every word after should be uppercase
# this is what we call camel otatio which is the covetio we use i
# JavaScript to ame our variables aother thig you eed to kow about these
# variable ames is they are case-sesitive so if I declare
# aother variable call it first ame but make the F uppercase these two variables
# are differet but as I told you before if you stick to camel otatio you
# would't ed up with a variable ame like this ad fially the last thig you
# eed to kow about these variables is that if you wat to declare multiple
# variables there are two ways to do this you ca declare them o oe lie ad
# separate them usig a comma so first ame ad the last ame ow i this case
# I have ot iitialized either of these variables they're both udefied I ca
# optioally iitialize oe or both of them so I ca set this to Marsh ad I
# ca leave last ame udefied or set it to my last ame Hammad o e but the
# moder best practice is to declare each variable o a sigle lie so we
# termiate this first declaratio with a semicolo ad declare the secod
# variable o a ew lie that's the moder best practice ext we're goig to look
# at costats alright ow let's declare a variable
# called iterest rate so let iterest rate ad we set this to 0.3 ow this is
# the iitial value we ca always chage that later so we ca set iterest rate
# to let's say 1 ow if you log this o the cosole of course we're goig to see
# the ew value right so save the chages ad here's oe o the cosole however i
# a real-world applicatio there are situatios that we do't wat the value
# of a variable to chage because otherwise it's goig to create all kids
# of bugs i our applicatio i those situatios istead of a variable we use
# a costat so the value of a variable as the ame implies ca chage but the
# value of a costat caot chage so here if we chage let to Cost ow
# iterest rate will be a costat so whe I save the chages you're goig to see
# a error i the cosole o lie 3 where we reassig iterest rate so let's have
# a look save the chages ad here's the error
# ucut type error assigmet 2 costat variable we ca see this error happe i
# idex dot JSP but if you click here you ca see the
# lie i code where this error occurred so we caot reassig a costat all
# right ow back to the cosole so here's the best practice if you do't eed to
# reassig costat should be your default choice otherwise if you eed to reassig
# a variable use let so you have leared how to declare ad
# iitialize a variable ow you might be woderig what are the kid of values
# that we ca assig to a variable well you have see strigs but we have more
# types basically i JavaScript we have two categories of types o oe side we
# have primitives also called value types ad the other types we have referece
# types i this lecture we're goig to focus o primitives ad you're goig to
# lear about referece types later i the course ow i the category of primitives
# we have strigs umbers bully eds udefied ad ot let's look at each of
# these i actio so here we have a variable called ame which is set to
# your strig what we have here is what we call a strig literal that's just a
# facy ame for a strig ow let's declare a variable ad set it to a
# umber so let H be set back to 30 ad by the way I'm ot 30 years old but do't
# tell ayoe okay so this is what we call a umber litora
# ow let's declare a boolea a boolea ca be either true or false
# so let is a proved to be true this is what we call a boolea literal ad we
# use this i situatios where we wat to have some logic for example if the order
# is approved the it eeds to be shipped so the value of a boolea variable ca
# be true or false ad by the way ote that both true ad false are reserved
# keywords so they caot be variable ames ok ow you have see udefied
# before so I ca declare aother variable first ame
# if we do't iitialize it by default its value is udefied
# but we ca also explicitly set this to udefied but that's ot very commo i
# cotrast we have aother keyword that is ot so let me declare aother variable
# ad set this to o we use ull i situatios where we wat to
# please heed me clear the value of variable for example you may wat to
# preset the user with a list of colors if the user has o selectio you wat to
# set the selected color variable to kow i the future if the user selects a
# color the we're goig to reassig this variable to a color like red ad the if
# they click red agai perhaps we wat to remove the selectio so we set this back
# tool ot so we use orm i situatios where we wat to clear the value of a
# variable so these are the examples of primitives or value types we have
# strigs umbers boolea's udefied ad o ow i es6 we have aother primitive
# that is symbol ad you're goig to lear about that later i the course oe thig that separates JavaScript from
# a lot of programmig laguages is that javascript is a dyamic laguage what do
# they mea by dyamic well we have two types of programmig laguages
# static laguages or dyamic laguages i static laguages whe we declare a
# variable the type of that variable is set ad it caot be chaged i the
# future i a dyamic laguage like JavaScript the type of a variable ca
# chage at rutime let's see this i code so back i the example from the last
# lecture we have declared this ame variable ad we have set that to your
# strig so the type of ame is curretly a strig but it ca chage i the future
# let's take a look so here i the cosole we ca execute some JavaScript code we
# have this type of operator ad with that we ca check the type of a variable so
# after that we add the ame of the variable i this case our ame variable
# so ote that the type of ame is a strig ow if we reassig ame to a
# differet value like a umber ad check its type look the type is ow chaged to
# a umber this is what we call a dyamic laguage so ulike static laguages the
# type of these variables will be determied at rutime based o the
# values that we assiged to them ow let's take a look at a few more examples
# of the type of operator ad by the way ote that type of is aother reserved
# keyword so you caot have a variable called type off so we ca clear the
# cosole by pressig ctrl + L so ow let's take a look at type of age it's a
# umber ow if you chage age to a floatig-poit umber ad I kow it
# does't make sese but let's just stick to this for this example thirty poit
# oe ad the look at type of age it's still a umber so i JavaScript ulike
# other programmig laguages we do't have two kids of umbers we do't have
# floatig-poit umbers ad itegers all umbers are of type umber ow let's
# look at the type of he's approved it's a boolea as I told you before what about
# the first ame let's have a look type of first ame it's udefied ad that's
# fuy because the value of this variable is udefied
# but this type is also udefied what does this mea well earlier I told you
# that we have two categories of types we have primitives or value types ad
# referece types i the primitive types category we have strigs umbers boolea
# udefied ad o so udefied is actually a type but is also a value i
# this example because we have set first-ame to udefied as a value it's
# type is also udefied okay ow what about selected color let's have a look
# so type of selected color the type of this variable is a object what is a
# object that's the topic for the ext lecture so you have see all the primitive types
# i JavaScript ow let's take a look at the referece types i the referece
# types category we have objects arrays ad fuctios i this lecture we're
# goig to explore objects ad you will lear about arrays ad fuctios later
# i this sectio so what is a object a object i JavaScript ad other
# programmig laguages is like a object i real life thik of a perso a perso
# has ame age address ad so o these are the properties of a perso you have the
# same cocept i JavaScript so whe we're dealig with multiple related variables
# we ca put these variables iside of a object for example here we have two
# variables ame ad age they're highly related they are part of the
# represetatio of a perso so istead of declarig two variables we ca declare a
# perso object ad the istead of referecig these two differet
# variables we ca just referece the perso object
# it makes our code cleaer so let's see how we ca declare a perso object we
# start with let or Cost if we do't wat to reassig the perso object ad set it
# to a object literal so this sytax we have here these curly braces is what we
# call a object literal ow betwee these curly braces we add oe or more key
# value pairs so the keys are what we call the properties of this object i this
# case we wat this perso object to have two properties or two keys ame ad age
# so we add ame here that's the key the we add a colo ad after that we set the
# value so maash ow we add a comma ad add aother key value pair age 30 so ow
# we have a perso object with two properties or two key value pairs ame
# ad age ad with that we do't eed these two variables ow this lock perso
# o the cosole so that log perso save the chages so
# here's our persoal object agai ote the object literal sytax so we have
# curly braces ad i betwee them we have oe or more key value pairs ad these
# are the properties of the persoal object ow there are two ways to work
# with these properties let's say we wat to chage the ame of this perso so we
# eed to access the ame property there are two ways the first way is what we
# call the dot otatio so we add the ame of our object i this case perso dot
# ow you ca see its properties we have age ad ame so we ca chage the value
# of ame to Joh ow we ca use the dot otatio to also read the value of a
# property so here o lie 10 istead of logi the perso object we ca log its
# ame property save the chages ad i the cosole we get Joh the other way to
# access a property is usig bracket otatio so bracket otatio so istead
# of dot we use square brackets ad we pass a strig that determies the ame
# of the target property so sigle or double quotes
# but sigle quotes are more commo the ame of the target property is ame so
# we ca chage that to a same Mary agai whe readig that we ca use the dot
# otatio or the bracket otatio if we save the chages ow we get Mary o the
# cosole ow you might be askig which approach is better dot otatio or
# bracket otatio well as you ca see dot otatio is a bit more cocise it's
# shorter so that should be your default choice however bracket otatio has its
# ow users sometimes you do't kow the ame of the target property util the
# rutime for example i our user iterface the user might be selectig
# the ame of the target property i that case at the time of writig code we
# do't kow what property we're goig to access that is
# goig to be selected at rutime by the user so we might have aother variable
# somewhere else like selectio that determies the ame of the target
# property that the user is selectig ad that ca chage at rutime with this we
# ca access that property usig the bracket otatio i a dyamic way so we
# pass selectio here ad we get the same result okay ow if this is cofusig
# do't worry you're goig to see this agai i the future as you gai more
# experiece with JavaScript for ow just stick to the dot otatio because that's
# cleaer ad easier ext we're goig to look at arrays sometimes i your applicatios you might
# be dealig with a list of objects for example the list of products i a
# shoppig cart or the list of colors the user has selected i situatios like
# that you use a array to store that list let me show you how so here I'm goa
# declare aother variable called selected colors ote that I'm usig a meaigful
# ame I do't have SC or some other weird ame selected colors ow we ca
# iitialize this ad set it to a empty array so these square brackets are what
# we call array literal ad they idicate a empty array ow we ca iitialize
# this array ad add a couple of items like red ad blue let's Lock this o the
# cosole so cosole the log selected colors save the chages so here's our
# array with two elemets we ca expad that ote that each elemet has a idex
# ad that determies the positio of that elemet i the array so the idex of the
# first elemet is zero ad the idex of the secod elemet is oe so if you wat
# to access a elemet i a array we use this idex here's how for example let's
# say you wat to display the first elemet i this array you use the square
# brackets ad the specify the idex save the chages ad ow we have red ow
# earlier I told you that JavaScript is a dyamic laguage so the type of
# variables ca chage at rutime the same priciple applies to our arrays so the
# legths of arrays as well as the type of objects we have i a array are dyamic
# they ca chage so aliged - we iitialize this array with two elemets
# right ow o lie 3 we ca add aother elemet to this array so the array will
# expad so let's say selected colors of 2 that meas the third item i this array
# is goig to be gree ow let's display this array o the cosole
# so we have a array with three elemets so the legth is dyamic it ca chage
# also the type of objects we have i this array is dyamic so ulike other
# programmig laguages where every item or every object i the array should have
# the same type i JavaScript we ca store differet types i a array so we ca
# make the last elemet a umber save the chages ow we have two strigs ad a
# umber so the objects i the array as well as the size of the array are
# dyamic ow techically a array is a object so just like the persoal object
# we defied i the last lecture it has a buch of key value pairs or properties
# that we ca access usig the dot otatio let me prove that to you so
# here o the cosole let's look at the type of selected colors so the type of
# this array is a object so a array is a object i JavaScript so here o lie
# 4 we ca look at the properties of this array or this object usig the dot
# otatio look these are all the properties defied i arrays i
# JavaScript so every time we declare a array usig square brackets that array
# will automatically receive these properties we did't explicitly defie
# them they're just somehow magically iherited from somewhere else we're
# goig to lear about that later whe we talk about prototypes ow i this
# lecture we're goig to look at oe of these properties that is the legth
# property this property returs the umber of items or elemets i a array
# so save the chages you ca see we have three elemets i this array ow later
# i the course we have a comprehesive sectio about arrays you'll lear about
# all kids of operatios we ca perform o arrays for ow all I wat you to take
# away is that a array is a data structure that we use to represet a
# list of items i the category of referece types you
# have leared about objects ad arrays ow let's take a look at fuctios
# fuctios are oe of the fudametal buildig blocks i JavaScript a fuctio
# is basically a set of statemets that performs a task or calculates a value
# let me show you a couple of examples so I'm goig to declare a fuctio usig
# the fuctio keyword ow we eed to give it a ame let's call that greet after
# that we eed to add paretheses that's part of the sytax for declarig
# fuctios ad the curly braces ow what we have here iside the curly braces is
# what we refer to as the body of this fuctio ad this is where we add all
# these statemets to defie some kid of logic i our applicatio for example the
# logic for this fuctio should be to display a message o the cosole so here
# we ca add cosole the log hello world ow ote that here we have a statemet
# so we termiated with a semicolo but whe we are declarig a fuctio we
# do't eed to add semicolo at the ed because we are ot declarig it like a
# variable like this okay this is a fuctio declaratio right so ow we
# have a fuctio we ca call this fuctio like this so we add the ame of
# the fuctio ad paretheses agai ad the semicolo to idicate that this is
# a statemet save the chages ow we have hello world o the cosole but that's
# pretty borig what would we do this let me show you how to make this more
# iterestig our fuctios ca have iputs ad these iputs ca chage how
# the fuctio behaves so let's say istead of displayig hello world we
# wat to display the ame of the perso here like hello Joh so we ca add a
# variable here i betwee paretheses we refer to this variable as a parameter
# so this greet fuctio has oe parameter called ame ad essetially ame is like
# a variable that is oly meaigful iside
# dysfuctio so iside of this fuctio we ca work with this ame variable but
# it will ot be accessible outside of this fuctio the ame is a iput to
# this fuctio so istead of displayig hello world we ca display hello
# the add a plus here to cocateate two strigs so we ca add ame after ow
# whe callig the great fuctio we eed to pass a value for the ame variable or
# ame parameter more accurately so we ca pass Joh here ow we refer to this as
# a argumet so Joh is a argumet to the greet fuctio a ame is a parameter
# of the greet fuctio it's oe of the thigs that a lot of programmers do't
# kow they do't kow the differece betwee a parameter ad a argumet so a
# parameter is what we have here at the time of declaratio but the argumet is
# the actual value with supply for that parameter okay
# ow let's save the chages so we have hello Joh ow we ca reuse this
# fuctio but with a differet iput so we ca copy this lie here ad chage o
# to Mary save the chages ow we have two differet messages o the cosole ow a
# fuctio ca have multiple parameters so here we ca separate parameters usig a
# comma so let's add aother parameter like last ame ow we ca chage our
# cosole ot blog add a space here ad the display the last ame
# ow whe callig this great fuctio we should pass aother argumet for the
# last ame right but let's see what happes if we do't do this so I'm goa
# save the chages see what we got hello Joh udefied
# because as I told you before the default value of variables i JavaScript is
# udefied so because we did ot pass a value for the last ame by default it's
# udefied so I'm goa pass aother argumet here we separate them usig a
# comma Joh Smith ad we do't eed the secod call to the
# greet fuctio save the chages ow we have hello Joh Smith ow there is a cleaer way to write this
# code o lie three all these cocateatios are kid of
# ugly they're gettig i the way later i the course I'll show you how to use
# template literals to clea up this code for ow do't worry about it let's look
# at aother example of a fuctio so this fuctio we have here is performig a
# task so performig a task is task is to display somethig o the cosole but
# sometimes our fuctios might calculate somethig so here is a example of a
# fuctio that calculates a value so agai fuctio let's call this fuctio
# square this fuctio should take a parameter let's call that umber ow we
# eed to calculate the square of that umber that is umber times umber just
# basic math right ow we eed to retur this value to whoever is callig this
# fuctio for that we use the retur keyword that's aother reserved keyword
# so you caot have a variable called retur okay ow istead of callig the
# greet fuctio let's call the square fuctio so square we pass two ow this
# returs a value so we ca use that value to iitialize a variable for example we
# ca declare aother variable called umber ad set it to a square of 2 ad
# the we ca display that o the cosole save the chages so we get 4 ow i this
# particular example we do't ecessarily have to declare a separate variable if
# all we wat to do is to display the square of 2 o the cosole we ca
# exclude this variable declaratio ad simply pass square of 2 to cosole.log
# so whe the JavaScript egie execute this code first is goig to call this
# fuctio it would get a value ad the pass that value to cosole dot lock
# let's save the chages ad look we still get 4 ow I have a questio for you how
# may fuctio calls do you thik we have i this code we have to fuctio costs
# square of two is oe fuctio call let me delete this temporarily but cosult
# that lock is also aother fuctio call right because here we have paretheses
# so recallig the log fuctio which is defied somewhere ad passig a
# argumet we ca pass a simple strig like hello or we ca pass a expressio
# that expressio ca be a call to aother fuctio like square of two okay so this
# is the basics of fuctios agai later i the course we have a comprehesive
# sectio about fuctios for ow all I wat you to take away is that a fuctio
# is a set of statemets that either performs a task or calculate ad returs
# a value a real world applicatio is essetially a collectio of hudreds or
# thousads of fuctios workig together to provide the fuctioality of that
# applicatio hi there it's me mosh agai you seem to
# be very ethusiastic about learig JavaScript so I wat to cogratulate you
# for your determiatio for learig if you wat to lear more from me I highly
# ecourage you to eroll i my JavaScript course you ca watch this course olie
# or offlie as may times as you wat at your ow pace the course comes with
# plety of exercises ad solutios ad you will also receive a certificate of
# completio by the ed of watchig the course i case you're iterested the
# lik is i the video descriptio have a great day ad I hope to see you i the
# course

# %%
summary = summarizer(subtitle, max_length = 180, min_length = 30)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2756/2533305639.py in <module>
# ----> 1 summary = summarizer(subtitle, max_length = 180, min_length = 30)
#
# ~\anaconda3\lib\site-packages\transformers\pipelines\text2text_generation.py in __call__(self, *args, **kwargs)
#     233               ids of the summary.
#     234         """
# --> 235         return super().__call__(*args, **kwargs)
#     236
#     237     def check_inputs(self, input_length: int, min_length: int, max_length: int) -> bool:
#
# ~\anaconda3\lib\site-packages\transformers\pipelines\text2text_generation.py in __call__(self, *args, **kwargs)
#     135         """
#     136
# --> 137         result = super().__call__(*args, **kwargs)
#     138         if (
#     139             isinstance(args[0], list)
#
# ~\anaconda3\lib\site-packages\transformers\pipelines\base.py in __call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1024             return self.iterate(inputs, preprocess_params, forward_params, postprocess_params)
#    1025         else:
# -> 1026             return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#    1027
#    1028     def run_multi(self, inputs, preprocess_params, forward_params, postprocess_params):
#
# ~\anaconda3\lib\site-packages\transformers\pipelines\base.py in run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1031     def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1032         model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1033         model_outputs = self.forward(model_inputs, **forward_params)
#    1034         outputs = self.postprocess(model_outputs, **postprocess_params)
#    1035         return outputs
#
# ~\anaconda3\lib\site-packages\transformers\pipelines\base.py in forward(self, model_inputs, **forward_params)
#     941                 with inference_context():
#     942                     model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# --> 943                     model_outputs = self._forward(model_inputs, **forward_params)
#     944                     model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#     945             else:
#
# ~\anaconda3\lib\site-packages\transformers\pipelines\text2text_generation.py in _forward(self, model_inputs, **generate_kwargs)
#     157         generate_kwargs["max_length"] = generate_kwargs.get("max_length", self.model.config.max_length)
#     158         self.check_inputs(input_length, generate_kwargs["min_length"], generate_kwargs["max_length"])
# --> 159         output_ids = self.model.generate(**model_inputs, **generate_kwargs)
#     160         out_b = output_ids.shape[0]
#     161         if self.framework == "pt":
#
# ~\anaconda3\lib\site-packages\torch\autograd\grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.clone():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# ~\anaconda3\lib\site-packages\transformers\generation_utils.py in generate(self, inputs, max_length, min_length, do_sample, early_stopping, num_beams, temperature, top_k, top_p, typical_p, repetition_penalty, bad_words_ids, force_words_ids, bos_token_id, pad_token_id, eos_token_id, length_penalty, no_repeat_ngram_size, encoder_no_repeat_ngram_size, num_return_sequences, max_time, max_new_tokens, decoder_start_token_id, use_cache, num_beam_groups, diversity_penalty, prefix_allowed_tokens_fn, logits_processor, stopping_criteria, constraints, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, forced_bos_token_id, forced_eos_token_id, remove_invalid_values, synced_gpus, exponential_decay_length_penalty, **model_kwargs)
#    1154             # if model is encoder decoder encoder_outputs are created
#    1155             # and added to `model_kwargs`
# -> 1156             model_kwargs = self._prepare_encoder_decoder_kwargs_for_generation(
#    1157                 inputs_tensor, model_kwargs, model_input_name
#    1158             )
#
# ~\anaconda3\lib\site-packages\transformers\generation_utils.py in _prepare_encoder_decoder_kwargs_for_generation(self, inputs_tensor, model_kwargs, model_input_name)
#     522         encoder_kwargs["return_dict"] = True
#     523         encoder_kwargs[model_input_name] = inputs_tensor
# --> 524         model_kwargs["encoder_outputs"]: ModelOutput = encoder(**encoder_kwargs)
#     525
#     526         return model_kwargs
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\anaconda3\lib\site-packages\transformers\models\bart\modeling_bart.py in forward(self, input_ids, attention_mask, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#     796             inputs_embeds = self.embed_tokens(input_ids) * self.embed_scale
#     797
# --> 798         embed_pos = self.embed_positions(input_shape)
#     799
#     800         hidden_states = inputs_embeds + embed_pos
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\anaconda3\lib\site-packages\transformers\models\bart\modeling_bart.py in forward(self, input_ids_shape, past_key_values_length)
#     135             past_key_values_length, past_key_values_length + seq_len, dtype=torch.long, device=self.weight.device
#     136         )
# --> 137         return super().forward(positions + self.offset)
#     138
#     139
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\sparse.py in forward(self, input)
#     156
#     157     def forward(self, input: Tensor) -> Tensor:
# --> 158         return F.embedding(
#     159             input, self.weight, self.padding_idx, self.max_norm,
#     160             self.norm_type, self.scale_grad_by_freq, self.sparse)
#
# ~\anaconda3\lib\site-packages\torch\nn\functional.py in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    2181         # remove once script supports set_grad_enabled
#    2182         _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 2183     return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#    2184
#    2185
#
# IndexError: index out of range in self
